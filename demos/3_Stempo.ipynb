# %%
#!/usr/bin/env python
"""
--------------------------------------------------------------------------
Created June 20, 2023 for TRIPs-Py library
"""
__author__ = "Mirjeta Pasha and Connor Sanderford"
__copyright__ = "Copyright 2022, TRIPs-Py library"
__license__ = "GPL"
__version__ = "0.1"
__maintainer__ = "Mirjeta Pasha"
__email__ = "mirjeta.pasha@tufts.edu; mirjeta.pasha1@gmail.com"
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from scipy.linalg import fractional_matrix_power
from numpy import array, diag, dot, maximum, empty, repeat, ones, sum
from numpy.linalg import inv
from trips.operators import *
##Specify the font
##Latex needs to be installed! If not installed, please comment the following 5 lines
parameters = {'xtick.labelsize': 12, 'ytick.labelsize': 12,
          'axes.titlesize': 18, 'axes.labelsize': 18, 'figure.titlesize': 14, 'legend.fontsize': 13}
plt.rcParams.update(parameters)
import time
import numpy as np
import scipy as sp
import scipy.stats as sps
import scipy.io as spio
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import astra
# import phantoms as phantom
from venv import create
import pylops
from scipy.ndimage import convolve
from scipy import sparse
from scipy.ndimage import convolve
import scipy.special as spe
from trips.testProblems import *
from trips.solvers.gks import *
import requests
from scipy import sparse
import numpy as np
import h5py
# functions to generate emoji data are stored in io_l.py
from trips.io import *
from trips.operators import *
from trips.solvers.AnisoTV import *

# %% [markdown]
# # Notebook 1: STEMPO test problem
#
# <p>In this example we illustrate the following:
# <p>&nbsp; Step 1: Download/read the STEMPO data and prepare them for processing.
# <p>&nbsp; Step 2: Solve the static inverse problem.
# <p>&nbsp; Step 3: Solve the dynamic inverse problem.
#
# CrossPhantom data are generated at the University of Helsinki: https://zenodo.org/record/7147139

# %% [markdown]
# #### Step 1: Download/read the data and prepare them for processing
# ##### The main function to generate the emoji data is generate_crossPhantom(dataset, noise_level)
# <p> <b>Input:</b>
# <p>&nbsp; <b>dataset:</b>
#         <p>&nbsp; if dataset = 15, we generate data from DataDynamic_128x15.mat
#         <p>&nbsp; if dataset = 60, we generate data from DataDynamic_128x60.mat
# <p>&nbsp; <b>noise_level:</b>
#         <p>&nbsp; CrossPhantom data are real data and they have noise. Hence, we set noise_level = 0
#
# <p> <b>Output:</b>
# &nbsp;<br> <b>A:</b> The full forward operator for all time instances<br>
# &nbsp; <b>b:</b> All the data/measurements vectorized<br>
# &nbsp; <b>AA:</b> A list of 16 time-wise operators<br>
# &nbsp; <b>B:</b> A list of 16 data vectors for each time instance <br>
# &nbsp; <b>nx:</b> The dimension of the first spatial domain<br>
# &nbsp; <b>ny:</b> The dimension of the second spatial domain<br>
# &nbsp; <b>nt:</b> The dimension of the time instances domain<br>
# &nbsp; <b>delta:</b> The noise level in the data. When we set noise_level == 0, we get delta = 0<br>
# &nbsp; <b>sinoshape:</b> The dimension of the time-wise sinogram<br>

# %%
(A, b, AA, B, nx, ny, nt, savedelta, truth) = get_stempo_data(data_set = 'simulation', data_thinning = '2')

# %% [markdown]
# #### Step 2: Solve the static inverse problems.
# <p>&nbsp; <b>The function to perform reconstruction is reconstruct_anisoTV(dynamic)</b>
# <p> <b>Input:</b>
# <p>&nbsp; <b>dynamic:</b>
#         <p>&nbsp; if dynamic = True, it solves the dynamic inverse problem $A x = b$
#         <p>&nbsp; if dynamic = False, it solves nt static inverse problems $AA(i) x(i) = B(i)$, for i in range(nt)
# <p> <b>Output:</b>
# &nbsp;<br> <b>xx:</b> <br>If dynamic == True, xx is a 3 dimensional tensor with dimensions (nx, ny, nt) that contains nt reconstructed images<br>If dynamic == False, xx is a list with nt elements that contains nt reconstructed images

# %%
A.shape
AA[1].shape
B[:, 1].shape
# Out:
# (8701,)

# %%
xx = list(range(nt))
L = spatial_derivative_operator(nx, ny, 1)
for i in range(nt):
    b_vec = B[:, i].reshape((-1,1))
    (x, x_history, lambdah, lambda_history) = MMGKS(AA[i], b_vec, L, pnorm=2, qnorm=1, projection_dim=3, iter = 10, regparam='gcv', x_true=None)
    xx[i] = x
# Out:
# generating basis...: 100%|██████████| 3/3 [00:00<00:00,  8.27it/s]
# running MMGKS...: 100%|██████████| 5/5 [02:38<00:00, 31.74s/it]
# generating basis...: 100%|██████████| 3/3 [00:00<00:00,  9.21it/s]
# running MMGKS...: 100%|██████████| 5/5 [02:36<00:00, 31.39s/it]
# generating basis...: 100%|██████████| 3/3 [00:00<00:00,  9.09it/s]
# running MMGKS...: 100%|██████████| 5/5 [02:35<00:00, 31.08s/it]
# generating basis...: 100%|██████████| 3/3 [00:00<00:00,  8.64it/s]
# running MMGKS...: 100%|██████████| 5/5 [02:42<00:00, 32.57s/it]
# generating basis...: 100%|██████████| 3/3 [00:00<00:00,  9.40it/s]
# running MMGKS...: 100%|██████████| 5/5 [02:37<00:00, 31.50s/it]
# generating basis...: 100%|██████████| 3/3 [00:00<00:00, 10.51it/s]
# running MMGKS...: 100%|██████████| 5/5 [02:43<00:00, 32.75s/it]
# generating basis...: 100%|██████████| 3/3 [00:00<00:00, 11.01it/s]
# running MMGKS...: 100%|██████████| 5/5 [02:38<00:00, 31.60s/it]
# generating basis...: 100%|██████████| 3/3 [00:00<00:00,  8.80it/s]
# running MMGKS...: 100%|██████████| 5/5 [02:36<00:00, 31.37s/it]
# generating basis...: 100%|██████████| 3/3 [00:00<00:00, 10.11it/s]
# running MMGKS...: 100%|██████████| 5/5 [02:44<00:00, 32.84s/it]
# generating basis...: 100%|██████████| 3/3 [00:00<00:00, 12.41it/s]
# running MMGKS...: 100%|██████████| 5/5 [02:41<00:00, 32.31s/it]
# generating basis...: 100%|██████████| 3/3 [00:00<00:00, 10.99it/s]
# running MMGKS...: 100%|██████████| 5/5 [02:48<00:00, 33.66s/it]
# generating basis...: 100%|██████████| 3/3 [00:00<00:00, 10.97it/s]
# running MMGKS...: 100%|██████████| 5/5 [02:48<00:00, 33.69s/it]
# generating basis...: 100%|██████████| 3/3 [00:00<00:00, 11.44it/s]
# running MMGKS...: 100%|██████████| 5/5 [02:48<00:00, 33.78s/it]
# generating basis...: 100%|██████████| 3/3 [00:00<00:00, 10.44it/s]
# running MMGKS...:  20%|██        | 1/5 [00:22<01:29, 22.26s/it]

# %%
xx = AnisoTV(A, b, AA, B, nx, ny, nt, dynamic = False, iters = 2, testproblem = 'STEMPO')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-6efac5aa24e4> in <module>
# ----> 1 xx = AnisoTV(A, b, AA, B, nx, ny, nt, dynamic = False, iters = 2, testproblem = 'STEMPO')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/trips/solvers/AnisoTV.py in AnisoTV(A, b, AA, B, nx, ny, nt, dynamic, iters, testproblem)
#      45             for i in range(nt):
#      46                 b_vec = B[i].reshape((-1,1))
# ---> 47                 (x, x_history, lambdah, lambda_history) = MMGKS(AA[i], b_vec, L, pnorm=2, qnorm=1, projection_dim=3, iter = 10, regparam='gcv', x_true=None)
#      48                 xx[i] = x
#      49     return xx
#
# ~/opt/anaconda3/lib/python3.8/site-packages/trips/solvers/gks.py in MMGKS(A, b, L, pnorm, qnorm, projection_dim, n_iter, regparam, x_true, **kwargs)
#     132
#     133     else:
# --> 134         (U, B, V) = generalized_golub_kahan(A, b, projection_dim, dp_stop, **kwargs)
#     135
#     136     x_history = []
#
# ~/opt/anaconda3/lib/python3.8/site-packages/trips/decompositions.py in generalized_golub_kahan(A, b, n_iter, dp_stop, **kwargs)
#     133     V = np.zeros((cols, 1))
#     134
# --> 135     U[:,0] = (b/np.linalg.norm(b)).flatten() # initialize U with the normalized guess
#     136
#     137     iterations = 0
#
# ValueError: could not broadcast input array from shape (20,) into shape (8701,)

# %%
from trips.io import *
# plot_recstructions_series(xx, (nx, ny, nt), dynamic = True, testproblem = 'crossPhantom', geome_x = 1,geome_x_small = 0,  save_imgs= False, save_path='./reconstruction/CrossPhantom')

# %%
plot_recstructions_series(xx, (nx, ny, nt), dynamic = True, testproblem = 'STEMPO', geome_x = 1,geome_x_small = 0,  save_imgs= False, save_path='./reconstruction/Stempo')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-48444a2a50ed> in <module>
# ----> 1 plot_recstructions_series(xx, (nx, ny, nt), dynamic = True, testproblem = 'crossPhantom', geome_x = 1,geome_x_small = 0,  save_imgs= False, save_path='./reconstruction/CrossPhantom')
#
# NameError: name 'plot_recstructions_series' is not defined

# %% [markdown]
# #### Step 3: Solve dynamic inverse problems.
# <p>&nbsp; <b>The function to perform reconstruction is reconstruct_anisoTV(dynamic)</b>
# <p> <b>Input:</b>
# <p>&nbsp; <b>dynamic:</b>
#         <p>&nbsp; if dynamic = True, it solves the dynamic inverse problem $A x = b$
#         <p>&nbsp; if dynamic = False, it solves nt static inverse problems $AA(i) x(i) = B(i)$, for i in range(nt)
# <p> <b>Output:</b>
# &nbsp;<br> <b>xx:</b> <br>If dynamic == True, xx is a 3 dimensional tensor with dimensions (nx, ny, nt) that contains nt reconstructed images<br>If dynamic == False, xx is a list with nt elements that contains nt reconstructed images

# %%
xx = AnisoTV(A, b, AA, B, nx, ny, nt, dynamic = True, iters = 5, testproblem = 'CrossPhantom')

# %%
plot_recstructions_series(xx, (nx, ny, nt), dynamic = True, testproblem = 'crossPhantom', geome_x = 1,geome_x_small = 0,  save_imgs= False, save_path='./reconstruction/CrossPhantom')

# %% [markdown]
# #### Step 4: Solve the problem by Golub-Kahan

# %%
b_vec = b.reshape((-1,1))
projection_dim = 30
(U, B, V) = generalized_golub_kahan(A, b_vec, projection_dim)
VV = V
UU = U[:, 0:-1]
HH = B[0:-1, :]
bhat = UU.T.dot(b_vec)
y_tikh = np.linalg.solve(HH.T*HH, bhat)
x_GKahan = VV.dot(y_tikh)
xx = np.reshape(x_GKahan, (nt, nx, ny))
xx.shape
plt.imshow(xx[1, :, :])
# Out:
# generating basis...: 100%|██████████| 30/30 [00:45<00:00,  1.53s/it]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pylops

from scipy import linalg as la
from scipy import sparse

from trips.io import build_x_true
from trips.operators import gaussian_blur_operator, first_derivative_operator
from trips.solvers.gks_all import MMGKS
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-e29e5b0c8597> in <module>
#       8 from trips.io import build_x_true
#       9 from trips.operators import gaussian_blur_operator, first_derivative_operator
# ---> 10 from trips.solvers.gks_all import MMGKS
#
# ~/Documents/Research_Projects/TRIPS_June25/multiparameter_package/trips/solvers/gks_all.py in <module>
#      13
#      14
# ---> 15 from ..decompositions import generalized_golub_kahan, arnoldi
#      16 from ..parameter_selection.gcv import generalized_crossvalidation
#      17 from ..parameter_selection.discrepancy_principle import discrepancy_principle
#
# ImportError: cannot import name 'generalized_golub_kahan' from 'trips.decompositions' (/Users/mirjetapasha/Documents/Research_Projects/TRIPS_June25/multiparameter_package/trips/decompositions.py)

# %% [markdown]
# ### construct a true image

# %%
x_true = build_x_true().reshape(-1,1)

plt.imshow(x_true.reshape(64,64), cmap='Greys_r')

# %% [markdown]
# ### apply an operator

# %%
blur_operator = gaussian_blur_operator([9,9],2,64,64)

b_true = blur_operator @ x_true

plt.imshow( b_true.reshape(64,64), cmap='Greys_r')

# %% [markdown]
# ### contaminate with noise

# %%
noise_level = 0.001
noise = np.random.randn(64*64)
e = noise_level * np.linalg.norm(b_true) / np.linalg.norm(noise) * noise
e = e.reshape(-1,1)
b = b_true + e
plt.imshow( b.reshape(64,64), cmap='Greys_r')

# %% [markdown]
# ### construct regularization operators

# %%
I = pylops.Identity(4096) # identity operator
D = first_derivative_operator(n=4096) # first derivative operator
D2 = D @ D # second derivative operator

# %% [markdown]
# ### run MMGKS with GCV

# %%
(x, x_history, lambdah, lambda_history, res_history, rre_history) = MMGKS(blur_operator, b, D, pnorm=2, qnorm=1, regparam='gcv', projection_dim=3, iter=80, x_true=x_true, tol=10**(-16))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/mirjetapasha/Documents/Research_Projects/TripsPY_May24/multiparameter_package/multiparameter_package/test_MMGKS.ipynb Cell 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/mirjetapasha/Documents/Research_Projects/TripsPY_May24/multiparameter_package/multiparameter_package/test_MMGKS.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> (x, x_history, lambdah, lambda_history, res_history, rre_history) = MMGKS(blur_operator, b, D, pnorm=2, qnorm=1, regparam='gcv', projection_dim=3, iter=80, x_true=x_true, tol=10**(-16))
#
# File ~/Documents/Research_Projects/TripsPY_May24/multiparameter_package/multiparameter_package/trips/solvers/gks.py:132, in MMGKS(A, b, L, pnorm, qnorm, projection_dim, iter, regparam, x_true, **kwargs)
#     129 if ((projection_method == 'auto') and (A.shape[0] == A.shape[1])) or (projection_method == 'arnoldi'):
#     131     if A.shape[0] == A.shape[1]:
# --> 132         (V,H) = arnoldi(A, projection_dim, b)
#     134     else:
#     135         (U, B, V) = generalized_golub_kahan(A, b, projection_dim, dp_stop, **kwargs)
#
# File ~/Documents/Research_Projects/TripsPY_May24/multiparameter_package/multiparameter_package/trips/decompositions.py:29, in arnoldi(A, b, n_iter, dp_stop, **kwargs)
#      26 H = np.zeros((cols, 1))
#      28 # normalize b
# ---> 29 b = b/np.linalg.norm(b, ord=2)
#      31 # b is first basis vector
#      32 Q[:, 0] = b[:,0]
#
# File <__array_function__ internals>:5, in norm(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/astra/lib/python3.9/site-packages/numpy/linalg/linalg.py:2611, in norm(x, ord, axis, keepdims)
#    2609     return ret
#    2610 else:
# -> 2611     raise ValueError("Improper number of dimensions to norm.")
#
# ValueError: Improper number of dimensions to norm.

# %%
plt.imshow(x.reshape(64,64), cmap='Greys_r')

# %% [markdown]
# ### Convergence

# %%
plt.scatter(range(len(rre_history)), rre_history, s=10)

# %% [markdown]
# ### history of solutions

# %%
fig, ax = plt.subplots(1, 8, figsize=(10, 10), sharey=True)

for ii in range(8):
    ax[ii].imshow(x_history[9+10*ii].reshape(64,64), cmap='Greys_r')

plt.show()

# %% [markdown]
# ### history of lambda values

# %%
plt.scatter(range(len(lambda_history)), lambda_history, s=10)

# %% [markdown]
# ### run MMGKS with DP

# %%
(x, x_history, lambdah, lambda_history, res_history, rre_history) = MMGKS(blur_operator, b, D, pnorm=2, qnorm=1, projection_dim=3, iter=80, regparam='dp', x_true=x_true, eta=1.01, delta=la.norm(e), tol=10**(-16))
# Out:
# generating basis...: 100%|██████████| 3/3 [00:00<00:00, 801.92it/s]
# running MMGKS...: 100%|██████████| 5/5 [00:00<00:00, 66.69it/s]

# %%
plt.imshow(x.reshape(64,64), cmap='Greys_r')

# %% [markdown]
# ### convergence

# %%
plt.scatter(range(len(rre_history)), rre_history, s=10)

# %% [markdown]
# ### history of solutions

# %%
fig, ax = plt.subplots(1, 8, figsize=(10, 10), sharey=True)

for ii in range(8):
    ax[ii].imshow(x_history[9+10*ii].reshape(64,64), cmap='Greys_r')

plt.show()

# %% [markdown]
# ### history of lambda values

# %%
plt.scatter(range(len(lambda_history)), lambda_history, s=10)

# %% [markdown]
# ### run MMGKS with a sequence of parameter values

# %%
regvals = [0.001*(0.5**(x)) for x in range(0,80)]

# %%
(x, x_history, lambdah, lambda_history, res_history, rre_history) = MMGKS(blur_operator, b, D, pnorm=2, qnorm=1, projection_dim=3, iter=80, regparam=regvals, x_true=x_true, tol=10**(-16))
# Out:
# generating basis...: 100%|██████████| 3/3 [00:00<00:00, 1499.39it/s]
# running MMGKS...: 100%|██████████| 80/80 [00:03<00:00, 22.57it/s]

# %%
plt.imshow(x.reshape(64,64), cmap='Greys_r')

# %% [markdown]
# ### convergence

# %%
plt.scatter(range(len(rre_history)), rre_history, s=10)

# %% [markdown]
# ### history of solutions

# %%
fig, ax = plt.subplots(1, 8, figsize=(10, 10), sharey=True)

for ii in range(8):
    ax[ii].imshow(x_history[9+10*ii].reshape(64,64), cmap='Greys_r')

plt.show()

# %% [markdown]
# ### history of lambda values

# %%
plt.scatter(range(len(lambda_history)), lambda_history, s=10)
